# %%
# Import Libraries 

import pandas as pd
import mysql.connector as mysql

# %%
# Create Connection 

mydb = mysql.connect( username='root', 
                      password='Keshav@123', 
                      database='demo')

# %%
# Write query to ALL data from the table 'select * from Table_name' which you use database give table name 

query = ' select * from t1 '

# %%
# Read sql panads DataFrame

df = pd.read_sql(query , mydb)
df
# Out:
#   Id           Name
# 0  1  Keshav Sharma
# 1  2  Keshav Sharma
# 2  3   Rahul Sharma
# 3  4          Pappu
# 4  5           None
# 5  6           None
# 6  7           None
